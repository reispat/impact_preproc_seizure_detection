# %%
# Figure 4 of "The impact of EEG preprocessing parameters on ultra-low-power seizure detection"

# imports
import seaborn as sns
import pandas as pd
import utils

# plotting settings
sns.set_theme(context='paper', style='ticks', font_scale=2, font="Arial")

# get data
df_folds_avg = pd.read_csv("./data/df_folds_avg_bit_width.csv")

# Plot figure 4

# define condition and metrics
condition = "bit_width"
metrics = ["event_sensitivity", "event_false_detections_per_hour", "event_average_detection_delay"]

# plot
utils.plot_condition(df_folds_avg, metrics, condition)

# %%
# Figure 5 of "The impact of EEG preprocessing parameters on ultra-low-power seizure detection"

# imports
import seaborn as sns
import pandas as pd
import utils

# plotting settings
sns.set_theme(context='paper', style='ticks', font_scale=2, font="Arial")

# get data
df_folds_avg = pd.read_csv("./data/df_folds_avg_n_channels.csv")

# Plot figure 5
# define condition and metrics
condition = "n_channels"
metrics = ["event_sensitivity", "event_false_detections_per_hour", "event_average_detection_delay"]

# plot
utils.plot_condition(df_folds_avg, metrics, condition)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\PatrickReisinger\miniconda3\envs\impact_preproc_seizure_detection\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'n_channels'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 20
#      17 metrics = ["event_sensitivity", "event_false_detections_per_hour", "event_average_detection_delay"]
#      19 # plot
# ---> 20 utils.plot_condition(df_folds_avg, metrics, condition)
#
# File c:\Users\PatrickReisinger\git\impact_preproc_seizure_detection\utils.py:21, in plot_condition(df_folds_avg, metrics, condition)
#      17 for ax, metric in zip(axes, metrics):
#      18
#      19     # get df
#      20     df_plot = df_folds_avg.copy()
# ---> 21     df_plot[condition] = df_plot[condition].astype(int).astype("string")
#      23     # drop na (plotting otherwise not possible)
#      24     df_plot.dropna(subset=[metric], inplace=True)
#
# File c:\Users\PatrickReisinger\miniconda3\envs\impact_preproc_seizure_detection\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\PatrickReisinger\miniconda3\envs\impact_preproc_seizure_detection\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'n_channels'

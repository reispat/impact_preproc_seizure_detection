# %%
# Figure 2 of "The impact of EEG preprocessing parameters on ultra-low-power seizure detection"

# imports
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import utils

# plotting settings
sns.set_theme(context='paper', style='ticks', font_scale=2, font="Arial")

# get data
df_folds_avg = pd.read_csv("./data/df_folds_avg_sampling_rates.csv")

# Plot figure 2

# define condition and metrics
condition = "sampling_rate"
metrics = ["event_sensitivity", "event_false_detections_per_hour", "event_average_detection_delay"]

# plot
utils.plot_condition(df_folds_avg, metrics, condition)

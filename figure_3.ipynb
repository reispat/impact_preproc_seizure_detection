# %%
# Figure 3 of "The impact of EEG preprocessing parameters on ultra-low-power seizure detection"

# imports
import seaborn as sns
import pandas as pd
import utils

# plotting settings
sns.set_theme(context='paper', style='ticks', font_scale=2, font="Arial")

# get data
df_folds_avg_no_overlap = pd.read_csv("./data/df_folds_avg_window_sizes_0_percent_overlap.csv")
df_folds_avg_overlap = pd.read_csv("./data/df_folds_avg_window_sizes_50_percent_overlap.csv")

# Plot figure 3
# define condition and metrics
condition = "window_length"
metrics = ["event_sensitivity", "event_false_detections_per_hour", "event_average_detection_delay"]

# plot
utils.plot_condition(df_folds_avg_no_overlap, metrics, condition) # figure 3A
utils.plot_condition(df_folds_avg_overlap, metrics, condition) # figure 3B
